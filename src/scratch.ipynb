# %%
# Package Import
from data_import import rawData
from utilities import dataframe_attributes, dataframe_overview_writeup

# %%
d_att = dataframe_attributes(rawData)
dataframe_overview_writeup('test', d_att)
# Out:
# 'Report name: test Your dataframe has 891 nobs and 15 ndim. There are 5 categorical variables, and 6 numeric columns.'

# %%
import pandas as pd

cool_df = pd.DataFrame(
    data = {
        'dtypes' : rawData.dtypes,
        'nunique' : rawData.nunique(),
        'NaN' : round(100*(rawData.isna().sum()/len(rawData)),3) 
    }
).sort_values(by = 'NaN', ascending = False)

cool_df
# Out:
#                dtypes  nunique     NaN
# deck         category        7  77.217
# age           float64       88  19.865
# embarked       object        3   0.224
# embark_town    object        3   0.224
# survived        int64        2   0.000
# pclass          int64        3   0.000
# sex            object        2   0.000
# sibsp           int64        7   0.000
# parch           int64        7   0.000
# fare          float64      248   0.000
# class        category        3   0.000
# who            object        3   0.000
# adult_male       bool        2   0.000
# alive          object        2   0.000
# alone            bool        2   0.000

# %%
from utilities import dataframe_info_table

dataframe_info_table(rawData)
# Out:
#                dtypes  nunique()     NaN
# deck         category          7  77.217
# age           float64         88  19.865
# embarked       object          3   0.224
# embark_town    object          3   0.224
# survived        int64          2   0.000
# pclass          int64          3   0.000
# sex            object          2   0.000
# sibsp           int64          7   0.000
# parch           int64          7   0.000
# fare          float64        248   0.000
# class        category          3   0.000
# who            object          3   0.000
# adult_male       bool          2   0.000
# alive          object          2   0.000
# alone            bool          2   0.000

# %%
rawData.describe().apply(lambda x: round(x, 2))
# Out:
#        survived  pclass     age   sibsp   parch    fare
# count    891.00  891.00  714.00  891.00  891.00  891.00
# mean       0.38    2.31   29.70    0.52    0.38   32.20
# std        0.49    0.84   14.53    1.10    0.81   49.69
# min        0.00    1.00    0.42    0.00    0.00    0.00
# 25%        0.00    2.00   20.12    0.00    0.00    7.91
# 50%        0.00    3.00   28.00    0.00    0.00   14.45
# 75%        1.00    3.00   38.00    1.00    0.00   31.00
# max        1.00    3.00   80.00    8.00    6.00  512.33

# %%
# Package Import
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Create df
df = rawData.describe().round(2)

# Create a matplotlib table from the dataframe
fig, ax = plt.subplots(figsize=(12, 7))
ax.axis('off')
ax.axis('tight')
table_data = np.vstack([list(df.index), df.values])
table = ax.table(cellText=table_data,
                 cellLoc='center',
                 colWidths=[0.2]*len(df.columns),
                 colLabels=['']+list(df.index),
                 )

# Set the font size of the table cells
table.auto_set_font_size(False)
table.set_fontsize(12)

# Save the table as a PNG file
plt.savefig('table.png', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\1/ipykernel_25092/4210398440.py in <module>
#      12 ax.axis('off')
#      13 ax.axis('tight')
# ---> 14 table_data = np.vstack([list(df.index), df.values])
#      15 table = ax.table(cellText=table_data,
#      16                  cellLoc='center',
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# c:\Users\dsimonds\Anaconda3\lib\site-packages\numpy\core\shape_base.py in vstack(tup)
#     281     if not isinstance(arrs, list):
#     282         arrs = [arrs]
# --> 283     return _nx.concatenate(arrs, 0)
#     284
#     285
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 8 and the array at index 1 has size 6

# %%
list(df.index)
# Out:
# ['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max']
