# %%
# Package Import
import data_import

# %%
# Read data
df = data_import.rawData

df.head() # titanic data
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Use main
import main
main.main(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Use main
#       2 import main
# ----> 3 main.main(df)
#
# File c:\Users\daves\OneDrive\Documents\GitHub\auto-eda\src\main.py:11, in main(dataframe, save_components)
#       8 def main(dataframe: pd.DataFrame, save_components = False):
#       9
#      10     # Cleanse any existing assets dir
# ---> 11     utilities.rm_dir('assets')
#      13     # Make a new assets dir
#      14     utilities.mk_assets_dir()
#
# File c:\Users\daves\OneDrive\Documents\GitHub\auto-eda\src\utilities.py:132, in rm_dir(dirname)
#     120 def rm_dir(dirname: str):
#     122     """
#     123     This function takes a dir name in the current working directory and deletes it.
#     124     It will also take care of all of the files saved within that directory.
#    (...)
# ...
